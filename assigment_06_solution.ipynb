# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# ## Question 1 solution
# 1. Some values in the the FlightNumber column are missing. These numbers are
# meant to increase by 10 with each row so 10055 and 10075 need to be put in
# place. Fill in these missing numbers and make the column an integer column
# (instead of a float column).

# %%
data['FlightNumber']
# Out:
# 0    10045.0
# 1        NaN
# 2    10065.0
# 3        NaN
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %%
for i in range(1,len(data)):
    if pd.isnull(data.FlightNumber.loc[i,]):
        data.loc[i,'FlightNumber'] = data.FlightNumber.loc[i-1] + 10

# %%
data['FlightNumber']
# Out:
# 0    10045.0
# 1    10055.0
# 2    10065.0
# 3    10075.0
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %%
data['FlightNumber'] = data['FlightNumber'].astype(int)

# %%
data['FlightNumber']
# Out:
# 0    10045
# 1    10055
# 2    10065
# 3    10075
# 4    10085
# Name: FlightNumber, dtype: int32

# %%
data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ## Question 2 solution
# 2. The From_To column would be better as two separate columns! Split each
# string on the underscore delimiter _ to give a new temporary DataFrame with
# the correct values. Assign the correct column names to this temporary
# DataFrame

# %%
data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
data['From_To']
# Out:
# 0        LoNDon_paris
# 1        MAdrid_miLAN
# 2    londON_StockhOlm
# 3      Budapest_PaRis
# 4     Brussels_londOn
# Name: From_To, dtype: object

# %%
tem_data = data.copy()

# %%
tem_data[['From','To']] = data['From_To'].str.split("_",expand = True)

# %%
tem_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# ## Question 3 solution
# 3. Notice how the capitalisation of the city names is all mixed up in this
# temporary DataFrame. Standardise the strings so that only the first letter is
# uppercase (e.g. "londON" should become "London".)

# %%
tem_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
# capitalisation in From_To column
tem_data['From_To'] = tem_data['From_To'].str.capitalize()

# %%
tem_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      London_paris         10045      [23, 47]               KLM(!)
# 1      Madrid_milan         10055            []    <Air France> (12)
# 2  London_stockholm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_paris         10075          [13]       12. Air France
# 4   Brussels_london         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
# capitalisation in From column
tem_data['From'] = tem_data['From'].str.capitalize()
# capitalisation in To column
tem_data['To'] = tem_data['To'].str.capitalize()

# %%
tem_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      London_paris         10045      [23, 47]               KLM(!)
# 1      Madrid_milan         10055            []    <Air France> (12)
# 2  London_stockholm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_paris         10075          [13]       12. Air France
# 4   Brussels_london         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# ## Question 4 solution
# 4. Delete the From_To column from df and attach the temporary DataFrame
# from the previous questions.

# %%
data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
tem_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      London_paris         10045      [23, 47]               KLM(!)
# 1      Madrid_milan         10055            []    <Air France> (12)
# 2  London_stockholm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_paris         10075          [13]       12. Air France
# 4   Brussels_london         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
data.drop(columns=['From_To'],inplace= True)

# %%
data
# Out:
#    FlightNumber  RecentDelays              Airline
# 0         10045      [23, 47]               KLM(!)
# 1         10055            []    <Air France> (12)
# 2         10065  [24, 43, 87]  (British Airways. )
# 3         10075          [13]       12. Air France
# 4         10085      [67, 32]          "Swiss Air"

# %%
data['From_to'] = tem_data['From_To']

# %%
data
# Out:
#    FlightNumber  RecentDelays              Airline           From_to
# 0         10045      [23, 47]               KLM(!)      London_paris
# 1         10055            []    <Air France> (12)      Madrid_milan
# 2         10065  [24, 43, 87]  (British Airways. )  London_stockholm
# 3         10075          [13]       12. Air France    Budapest_paris
# 4         10085      [67, 32]          "Swiss Air"   Brussels_london

# %% [markdown]
# ## Question 5 solution
# 5. In the RecentDelays column, the values have been entered into the
# DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value
# should be NaN.
# Expand the Series of lists into a DataFrame named delays, rename the columns
# delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df
# with delays.

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df_delays=pd.DataFrame(df["RecentDelays"].values.tolist())
df_delays.columns = ['delay_{}'.format(n) for n in range(1, len(df_delays.columns)+1)]
df_delays
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df_Analysis=df.drop("RecentDelays" , axis=1).join(df_delays)
print("Output")
df_Analysis
# Out:
# Output
#             From_To  FlightNumber              Airline  delay_1  delay_2  \
# 0      LoNDon_paris       10045.0               KLM(!)     23.0     47.0
# 1      MAdrid_miLAN           NaN    <Air France> (12)      NaN      NaN
# 2  londON_StockhOlm       10065.0  (British Airways. )     24.0     43.0
# 3    Budapest_PaRis           NaN       12. Air France     13.0      NaN
# 4   Brussels_londOn       10085.0          "Swiss Air"     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN
