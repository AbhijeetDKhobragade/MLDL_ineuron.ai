# %% [markdown]
# ## Question no 1 solution

# %%
n = 5
for i in range(n):
    for j in range(i):
        print('*' , end=' ')
    print()
    
for i in range(n):
    for k in range(i,n):
        print('*' , end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ## Question no 2 solution

# %%
input_word = 'ineuron'
print(input_word[::-1])
# Out:
# norueni
